# %%
import xgboost as xgb
import numpy as np
import pandas as pd
import time

# %%
# !wget -N https://gitlab.com/dzwietering/corona/-/raw/master/zzprogress.csv
# !wget -N https://www.acaps.org/sites/acaps/files/resources/files/acaps_covid19_government_measures_dataset.xlsx
# Out:
# --2020-06-04 19:39:05--  https://gitlab.com/dzwietering/corona/-/raw/master/zzprogress.csv
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘zzprogress.csv’
#
# zzprogress.csv          [ <=>                ]  31.50K  --.-KB/s    in 0.01s
#
# Last-modified header missing -- time-stamps turned off.
# 2020-06-04 19:39:05 (2.39 MB/s) - ‘zzprogress.csv’ saved [32257]
#
# --2020-06-04 19:39:06--  https://www.acaps.org/sites/acaps/files/resources/files/acaps_covid19_government_measures_dataset.xlsx
# Resolving www.acaps.org (www.acaps.org)... 151.80.35.46
# Connecting to www.acaps.org (www.acaps.org)|151.80.35.46|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-06-04 19:39:06 ERROR 404: Not Found.

# %%
df_prog = pd.read_csv('zzprogress.csv', parse_dates=[8, 9, 10])
df_prog
# Out:
#     iso2                         cname iso3    ccont     popdata  rsquared  \
# 0     AD                       Andorra  AND   Europe     77006.0  0.955327
# 1     AE          United_Arab_Emirates  ARE     Asia   9630959.0  0.994398
# 2     AF                   Afghanistan  AFG     Asia  37172386.0  0.994937
# 3     AG           Antigua_and_Barbuda  ATG  America     96286.0  0.983465
# 4     AL                       Albania  ALB   Europe   2866376.0  0.993561
# ..   ...                           ...  ...      ...         ...       ...
# 175   VG        British_Virgin_Islands  VGB  America     29802.0  0.960652
# 176   VI  United_States_Virgin_Islands  VIR  America    106977.0  0.966921
# 177   XK                        Kosovo  XKX   Europe   1845300.0  0.992235
# 178   ZA                  South_Africa  ZAF   Africa  57779622.0  0.978311
# 179   ZM                        Zambia  ZMB   Africa  17351822.0  0.995188
#
#      progress          final      start       peak      floor       beta  \
# 0    1.144845     637.141572 2020-03-18 2020-03-31 2020-05-15   6.149978
# 1    0.666050   48669.864101 2020-03-22 2020-05-12 2020-09-25  25.670654
# 2    0.175031   74888.936321 2020-04-18 2020-06-25 2020-11-28  39.706238
# 3    0.990206      23.660298 2020-03-23 2020-04-05 2020-05-02   7.927100
# 4    0.905945    1171.941731 2020-03-14 2020-04-16 2020-06-20  22.738032
# ..        ...            ...        ...        ...        ...        ...
# 175  0.730127       8.217750 2020-03-28 2020-04-27 2020-06-20  22.522308
# 176  0.783359      48.873759 2020-03-17 2020-04-17 2020-06-18  20.170511
# 177  0.935607    1108.524566 2020-03-22 2020-04-18 2020-06-17  16.698912
# 178  0.035563  748449.237279 2020-04-05 2020-09-11        NaT  81.831457
# 179  1.085406     935.923468 2020-05-11 2020-05-17 2020-05-30   5.663459
#
#              mu        maxcur
# 0     91.156126    439.684610
# 1    132.693121   9641.819054
# 2    176.920979   9664.442637
# 3     95.526361     13.604696
# 4    107.286087    261.264417
# ..          ...           ...
# 175  117.520926      1.848767
# 176  107.945431     12.230366
# 177  109.349854    331.986753
# 178  254.968956  48963.953206
# 179  138.281355    680.472542
#
# [180 rows x 14 columns]

# %%
df_meas = pd.read_excel('acaps_covid19_government_measures_dataset.xlsx', sheet_name='Database')
df_meas
# Out:
#           ID      COUNTRY  ISO ADMIN_LEVEL_NAME  PCODE  REGION  \
# 0          1  Afghanistan  AFG              NaN    NaN    Asia
# 1          2  Afghanistan  AFG            Kabul    NaN    Asia
# 2          3  Afghanistan  AFG              NaN    NaN    Asia
# 3          4  Afghanistan  AFG              NaN    NaN    Asia
# 4          5  Afghanistan  AFG              NaN    NaN    Asia
# ...      ...          ...  ...              ...    ...     ...
# 12337  11771     Zimbabwe  ZWE              NaN    NaN  Africa
# 12338  11772     Zimbabwe  ZWE              NaN    NaN  Africa
# 12339  11773     Zimbabwe  ZWE              NaN    NaN  Africa
# 12340  11774     Zimbabwe  ZWE              NaN    NaN  Africa
# 12341  11775     Zimbabwe  ZWE              NaN    NaN  Africa
#
#                                    LOG_TYPE  \
# 0      Introduction / extension of measures
# 1      Introduction / extension of measures
# 2      Introduction / extension of measures
# 3      Introduction / extension of measures
# 4      Introduction / extension of measures
# ...                                     ...
# 12337  Introduction / extension of measures
# 12338  Introduction / extension of measures
# 12339  Introduction / extension of measures
# 12340                     Phase-out measure
# 12341                     Phase-out measure
#
#                                      CATEGORY  \
# 0                      Public health measures
# 1                      Public health measures
# 2                      Public health measures
# 3      Governance and socio-economic measures
# 4                           Social distancing
# ...                                       ...
# 12337                                Lockdown
# 12338                  Public health measures
# 12339                                Lockdown
# 12340                       Social distancing
# 12341                       Social distancing
#
#                                                  MEASURE TARGETED_POP_GROUP  \
# 0      Health screenings in airports and border cross...                 No
# 1                      Isolation and quarantine policies                 No
# 2                                    Awareness campaigns                 No
# 3      Emergency administrative structures activated ...                 No
# 4                                Limit public gatherings                 No
# ...                                                  ...                ...
# 12337                                   Partial lockdown                 No
# 12338      Requirement to wear protective gear in public                 No
# 12339                                   Partial lockdown                 No
# 12340                            Limit public gatherings                 No
# 12341                            Limit public gatherings                 No
#
#                                                 COMMENTS    NON_COMPLIANCE  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                              Nevruz festival cancelled               NaN
# ...                                                  ...               ...
# 12337  Partial lockdown (level 2) extended indefinite...     Not available
# 12338  The government of Zimbabwe has officially made...  Arrest/Detention
# 12339           Zimbabwe extends lockdown until May 15th     Not available
# 12340  Outdoor exercises like walking or jogging or c...    Not applicable
# 12341  Athletes taking part in low-risk sports, inclu...    Not applicable
#
#       DATE_IMPLEMENTED               SOURCE SOURCE_TYPE  \
# 0           2020-02-12   Ministry of Health  Government
# 1           2020-02-12   Ministry of Health  Government
# 2           2020-02-12   Ministry of Health  Government
# 3           2020-02-12   Ministry of Health  Government
# 4           2020-03-12                   AA       Media
# ...                ...                  ...         ...
# 12337       2020-05-17  Zimbabwe Government  Government
# 12338       2020-05-04          Africa News       Media
# 12339       2020-05-04                Garda       Media
# 12340       2020-05-17  Zimbabwe Government  Government
# 12341       2020-05-17  Zimbabwe Government  Government
#
#                                                     LINK ENTRY_DATE  \
# 0      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 1      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 2      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 3      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 4      https://www.aa.com.tr/en/asia-pacific/coronavi... 2020-03-14
# ...                                                  ...        ...
# 12337  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
# 12338  https://www.africanews.com/2020/05/10/zimbabwe... 2020-05-25
# 12339  https://www.garda.com/crisis24/news-alerts/339... 2020-05-25
# 12340  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
# 12341  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
#
#                                       Alternative source
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12337   https://zw.usembassy.gov/covid-19-information-2/
# 12338  https://www.garda.com/crisis24/news-alerts/339...
# 12339                                                NaN
# 12340                                                NaN
# 12341                                                NaN
#
# [12342 rows x 18 columns]

# %%
df_full = pd.merge(df_prog, df_meas, left_on='iso3', right_on='ISO')
df_full
# Out:
#       iso2                 cname iso3   ccont     popdata  rsquared  progress  \
# 0       AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994398  0.666050
# 1       AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994398  0.666050
# 2       AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994398  0.666050
# 3       AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994398  0.666050
# 4       AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994398  0.666050
# ...    ...                   ...  ...     ...         ...       ...       ...
# 10595   ZM                Zambia  ZMB  Africa  17351822.0  0.995188  1.085406
# 10596   ZM                Zambia  ZMB  Africa  17351822.0  0.995188  1.085406
# 10597   ZM                Zambia  ZMB  Africa  17351822.0  0.995188  1.085406
# 10598   ZM                Zambia  ZMB  Africa  17351822.0  0.995188  1.085406
# 10599   ZM                Zambia  ZMB  Africa  17351822.0  0.995188  1.085406
#
#               final      start       peak  ...  \
# 0      48669.864101 2020-03-22 2020-05-12  ...
# 1      48669.864101 2020-03-22 2020-05-12  ...
# 2      48669.864101 2020-03-22 2020-05-12  ...
# 3      48669.864101 2020-03-22 2020-05-12  ...
# 4      48669.864101 2020-03-22 2020-05-12  ...
# ...             ...        ...        ...  ...
# 10595    935.923468 2020-05-11 2020-05-17  ...
# 10596    935.923468 2020-05-11 2020-05-17  ...
# 10597    935.923468 2020-05-11 2020-05-17  ...
# 10598    935.923468 2020-05-11 2020-05-17  ...
# 10599    935.923468 2020-05-11 2020-05-17  ...
#
#                                                  MEASURE  TARGETED_POP_GROUP  \
# 0                                      Visa restrictions                 Yes
# 1                                      Visa restrictions                  No
# 2                       International flights suspension                 Yes
# 3      Health screenings in airports and border cross...                 Yes
# 4      Health screenings in airports and border cross...                  No
# ...                                                  ...                 ...
# 10595                                    Border closure                  Yes
# 10596                       Domestic travel restrictions                 Yes
# 10597                                    Border closure                  Yes
# 10598                                   Schools closure                  Yes
# 10599             Strengthening the public health system                 Yes
#
#                                                 COMMENTS  NON_COMPLIANCE  \
# 0      entry ban for travellers from Iran (no governm...             NaN
# 1          suspension of visa issuance starting March 17             NaN
# 2      flights to and from Iran and China are suspend...             NaN
# 3      passengers arriving from China will undergo he...             NaN
# 4           health sreenings for all passengers arriving             NaN
# ...                                                  ...             ...
# 10595  Nakonde Boarder to temporarily close tomorrow ...  Not applicable
# 10596  There will be a suspension of public road and ...  Not applicable
# 10597  Zambia reopened its Nakonde border with Tanzan...  Not applicable
# 10598  Zambia will begin opening schools on the 1st o...  Not applicable
# 10599  Government is procuring 1.3 million masks for ...  Not applicable
#
#        DATE_IMPLEMENTED                       SOURCE   SOURCE_TYPE  \
# 0            2020-01-02                      Reuters         Media
# 1            2020-03-17                          NYT         Media
# 2            2020-03-17  Ministry of Foreign Affairs    Government
# 3            2020-01-23                 KhaleejTimes         Media
# 4            2020-03-08                   US Embassy    Government
# ...                 ...                          ...           ...
# 10595        2020-05-11          Ministry of Health   Social media
# 10596        2020-05-11          Ministry of Health   Social media
# 10597        2020-05-15                         CGTN         Media
# 10598        2020-06-01      Ministry of Information  Social media
# 10599        2020-06-01      Ministry of Information  Social media
#
#                                                     LINK  ENTRY_DATE  \
# 0      https://www.reuters.com/article/us-healthcare-...  2020-03-16
# 1      https://www.nytimes.com/reuters/2020/03/14/wor...  2020-03-16
# 2      https://www.mofaic.gov.ae/en/mediahub/news/202...  2020-03-16
# 3      https://www.khaleejtimes.com/uae/dubai/china-c...  2020-03-16
# 4         https://ae.usembassy.gov/covid-19-information/  2020-03-16
# ...                                                  ...         ...
# 10595                https://www.facebook.com/mohzambia/  2020-05-13
# 10596                https://www.facebook.com/mohzambia/  2020-05-13
# 10597  https://africa.cgtn.com/2020/05/15/zambia-reop...  2020-05-15
# 10598  https://www.facebook.com/permalink.php?story_f...  2020-05-23
# 10599  https://www.facebook.com/permalink.php?story_f...  2020-05-23
#
#                                       Alternative source
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10595  https://www.aa.com.tr/en/africa/covid-19-zambi...
# 10596  https://www.aa.com.tr/en/africa/covid-19-zambi...
# 10597                                                NaN
# 10598                                                NaN
# 10599                                                NaN
#
# [10600 rows x 32 columns]

# %%
df_full['days'] = (df_full['DATE_IMPLEMENTED'] - df_full['start']).dt.days
df_full['days'].describe()
# Out:
# count    10070.000000
# mean        16.670606
# std         35.395747
# min       -132.000000
# 25%         -6.000000
# 50%         15.000000
# 75%         44.000000
# max        161.000000
# Name: days, dtype: float64

# %%
df_aggr = df_full.pivot_table(index='iso2', columns='CATEGORY', values='days')
df_aggr
# Out:
# CATEGORY  Governance and socio-economic measures  Humanitarian exemption  \
# iso2
# AE                                      2.000000                     NaN
# AF                                    -53.800000                     NaN
# AG                                     16.333333                     NaN
# AL                                      9.733333                     NaN
# AM                                     32.750000                     NaN
# ...                                          ...                     ...
# UZ                                           NaN                     NaN
# VC                                           NaN                     NaN
# VE                                    -36.111111                     NaN
# ZA                                     11.933333                     NaN
# ZM                                    -37.000000                     NaN
#
# CATEGORY   Lockdown  Movement restrictions  Public health measures  \
# iso2
# AE        14.500000              25.523810               -3.200000
# AF       -21.000000             -44.555556              -47.343750
# AG        32.142857              37.500000               -0.300000
# AL        24.500000              20.200000               -6.416667
# AM        33.500000              18.375000               19.000000
# ...             ...                    ...                     ...
# UZ              NaN             -14.000000                     NaN
# VC              NaN                    NaN               -0.222222
# VE       -18.000000             -33.181818              -31.600000
# ZA        19.500000              19.300000               19.947368
# ZM              NaN             -27.000000              -43.636364
#
# CATEGORY  Social distancing
# iso2
# AE                24.375000
# AF               -35.333333
# AG                 5.625000
# AL                23.076923
# AM                30.000000
# ...                     ...
# UZ                      NaN
# VC                -6.000000
# VE               -65.400000
# ZA                32.944444
# ZM               -24.153846
#
# [153 rows x 6 columns]

# %%
df_final = pd.merge(df_prog, df_aggr, left_on='iso2', right_index=True)
df_final
# Out:
#     iso2                             cname iso3    ccont     popdata  \
# 1     AE              United_Arab_Emirates  ARE     Asia   9630959.0
# 2     AF                       Afghanistan  AFG     Asia  37172386.0
# 3     AG               Antigua_and_Barbuda  ATG  America     96286.0
# 4     AL                           Albania  ALB   Europe   2866376.0
# 5     AM                           Armenia  ARM   Europe   2951776.0
# ..   ...                               ...  ...      ...         ...
# 171   UZ                        Uzbekistan  UZB     Asia  32955400.0
# 173   VC  Saint_Vincent_and_the_Grenadines  VCT  America    110210.0
# 174   VE                         Venezuela  VEN  America  28870195.0
# 178   ZA                      South_Africa  ZAF   Africa  57779622.0
# 179   ZM                            Zambia  ZMB   Africa  17351822.0
#
#      rsquared  progress          final      start       peak      floor  \
# 1    0.994398  0.666050   48669.864101 2020-03-22 2020-05-12 2020-09-25
# 2    0.994937  0.175031   74888.936321 2020-04-18 2020-06-25 2020-11-28
# 3    0.983465  0.990206      23.660298 2020-03-23 2020-04-05 2020-05-02
# 4    0.993561  0.905945    1171.941731 2020-03-14 2020-04-16 2020-06-20
# 5    0.971974  0.266875   30601.255293 2020-03-09 2020-06-23 2021-04-03
# ..        ...       ...            ...        ...        ...        ...
# 171  0.961278  0.940004    3646.034605 2020-04-08 2020-04-28 2020-05-28
# 173  0.913497  1.161390      18.450799 2020-03-24 2020-04-13 2020-05-19
# 174  0.997226  1.200132    1088.094324 2020-05-20 2020-05-25 2020-06-04
# 178  0.978311  0.035563  748449.237279 2020-04-05 2020-09-11        NaT
# 179  0.995188  1.085406     935.923468 2020-05-11 2020-05-17 2020-05-30
#
#           beta          mu        maxcur  \
# 1    25.670654  132.693121   9641.819054
# 2    39.706238  176.920979   9664.442637
# 3     7.927100   95.526361     13.604696
# 4    22.738032  107.286087    261.264417
# 5    53.976786  175.273967   2916.644063
# ..         ...         ...           ...
# 171  19.629614  118.547484    936.266527
# 173  15.636498  103.907525      5.878634
# 174   5.080584  146.432436    841.073032
# 178  81.831457  254.968956  48963.953206
# 179   5.663459  138.281355    680.472542
#
#      Governance and socio-economic measures  Humanitarian exemption  \
# 1                                  2.000000                     NaN
# 2                                -53.800000                     NaN
# 3                                 16.333333                     NaN
# 4                                  9.733333                     NaN
# 5                                 32.750000                     NaN
# ..                                      ...                     ...
# 171                                     NaN                     NaN
# 173                                     NaN                     NaN
# 174                              -36.111111                     NaN
# 178                               11.933333                     NaN
# 179                              -37.000000                     NaN
#
#       Lockdown  Movement restrictions  Public health measures  \
# 1    14.500000              25.523810               -3.200000
# 2   -21.000000             -44.555556              -47.343750
# 3    32.142857              37.500000               -0.300000
# 4    24.500000              20.200000               -6.416667
# 5    33.500000              18.375000               19.000000
# ..         ...                    ...                     ...
# 171        NaN             -14.000000                     NaN
# 173        NaN                    NaN               -0.222222
# 174 -18.000000             -33.181818              -31.600000
# 178  19.500000              19.300000               19.947368
# 179        NaN             -27.000000              -43.636364
#
#      Social distancing
# 1            24.375000
# 2           -35.333333
# 3             5.625000
# 4            23.076923
# 5            30.000000
# ..                 ...
# 171                NaN
# 173          -6.000000
# 174         -65.400000
# 178          32.944444
# 179         -24.153846
#
# [153 rows x 20 columns]

# %%
df_final['mcpop'] = df_final['maxcur'] / df_final['popdata']
df_final['mcpop'].describe()
# Out:
# count    153.000000
# mean       0.000536
# std        0.001017
# min        0.000013
# 25%        0.000055
# 50%        0.000153
# 75%        0.000672
# max        0.008429
# Name: mcpop, dtype: float64

# %%
# %matplotlib inline

df_final['mcpop'].hist(bins=50,)

# %%
# %matplotlib inline

df_final.plot(kind="scatter", x="mcpop", y="Lockdown", alpha=0.4)

# %%
# %matplotlib inline

df_final.plot(kind="scatter", x="mcpop", y="beta", alpha=.4)

# %%
from sklearn.model_selection import train_test_split, KFold

features = df_final.columns[14:19]

x_train, x_test, y_train, y_test = train_test_split(df_final[features], df_final["mcpop"])

# %%
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test)

params = {
    'objective' : 'reg:linear',
    #'tree_method':'hist',
    'min_child_weight' : 1,
    'eta' : 0.3,
    'seed' : 0,
    'gamma':0,
    'max_depth': 3,
    # 'colsample_bytree': 0.7,
    # 'subsample':0.7,
}

hist = xgb.cv(params, dtrain, nfold=3, as_pandas=True, num_boost_round=2000, verbose_eval=100, early_stopping_rounds=2000, show_stdv=True, seed=0)
# Out:
# [20:31:00] WARNING: /workspace/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:00] WARNING: /workspace/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# [20:31:00] WARNING: /workspace/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	train-rmse:0.35154+0.00004	test-rmse:0.35154+0.00012
# [100]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [200]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [300]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [400]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [500]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [600]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [700]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [800]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [900]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1000]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1100]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1200]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1300]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1400]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1500]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1600]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1700]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1800]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1900]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039
# [1999]	train-rmse:0.00048+0.00004	test-rmse:0.00100+0.00039

# %% [markdown]
# ## OMG ! Look at that overfitting!

# %%
hist.plot(y=["test-rmse-mean", "train-rmse-mean"])

# %%
## xgboost on training data
bst = xgb.train(params, dtrain, num_boost_round=2000, verbose_eval=100)
# Out:
# [20:27:01] WARNING: /workspace/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:01] WARNING: /workspace/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(10, 20))

xgb.plot_importance(bst, ax=ax, height=0.4)
