# %% [markdown]
# Using basic libraries for calculation, data and modeling.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Check current folder, get updated files if available.

# %%
# !pwd
#!wget -N https://gitlab.com/dzwietering/corona/-/raw/master/zzprogress.csv
#!wget -N https://www.acaps.org/sites/acaps/files/resources/files/acaps_covid19_government_measures_datasets.xlsx
# Out:
# /home/zwieteri/git/corona/experiment

# %% [markdown]
# Read the generated country progress file, read the proper columns as dates.

# %%
df_prog = pd.read_csv('zzprogress.csv', parse_dates=[8, 9, 10])
df_prog
# Out:
#     iso2                         cname iso3    ccont     popdata  rsquared  \
# 0     AD                       Andorra  AND   Europe     77006.0  0.957238
# 1     AE          United_Arab_Emirates  ARE     Asia   9630959.0  0.994810
# 2     AF                   Afghanistan  AFG     Asia  37172386.0  0.996008
# 3     AG           Antigua_and_Barbuda  ATG  America     96286.0  0.944507
# 4     AL                       Albania  ALB   Europe   2866376.0  0.986111
# ..   ...                           ...  ...      ...         ...       ...
# 179   VI  United_States_Virgin_Islands  VIR  America    106977.0  0.949531
# 180   XK                        Kosovo  XKX   Europe   1845300.0  0.990807
# 181   ZA                  South_Africa  ZAF   Africa  57779622.0  0.982011
# 182   ZM                        Zambia  ZMB   Africa  17351822.0  0.991399
# 183   ZW                      Zimbabwe  ZWE   Africa  14439018.0  0.964637
#
#      progress         final      start       peak      floor       beta  \
# 0    1.203215  6.579989e+02 2020-03-18 2020-04-01 2020-05-17   6.362408
# 1    0.687086  5.285733e+04 2020-03-22 2020-05-14 2020-10-04  26.767732
# 2    0.175963  9.835843e+04 2020-04-18 2020-07-02 2020-12-24  42.528719
# 3    1.272729  1.885712e+01 2020-03-25 2020-04-03 2020-04-23   5.465425
# 4    0.883503  1.323303e+03 2020-03-13 2020-04-21 2020-07-04  26.514643
# ..        ...           ...        ...        ...        ...        ...
# 179  0.989458  3.999303e+01 2020-03-23 2020-04-13 2020-05-28  13.401817
# 180  0.951309  1.152698e+03 2020-03-21 2020-04-20 2020-06-23  18.091216
# 181  0.020943  1.700736e+06 2020-04-05 2020-10-15        NaT  93.700186
# 182  1.116582  9.833581e+02 2020-05-10 2020-05-18 2020-05-31   6.272693
# 183  1.499994  1.502863e+02 2020-06-01 2020-06-02 2020-06-03   3.584852
#
#              mu         maxcur
# 0     91.513397     443.688824
# 1    134.802109   10052.922187
# 2    183.783975   11860.256406
# 3     93.869789      14.004713
# 4    111.534498     254.030214
# ..          ...            ...
# 179  103.966302      14.694267
# 180  110.622583     319.988943
# 181  289.050346  101277.107740
# 182  138.763116     668.495820
# 183  153.444411     135.481043
#
# [184 rows x 14 columns]

# %% [markdown]
# Have a look at the countries with the highest estimated part of the population concurrently infected. Therefore, we divide the maximum current from the estimate by the population data. We use a log scale due to large differences and show countries with values above 1 per thousand.

# %%
df_prog['mcpop'] = df_prog['maxcur'] / df_prog['popdata']
df_prog[df_prog['mcpop'] > 1/1000].sort_values(by=['mcpop']).plot(
    x='iso2', y='mcpop', kind='barh', logx=True, figsize=(16, 9), grid=True)

# %% [markdown]
# The log of infected seems a good initial measure, so we define it as target.

# %%
df_prog['target'] = np.log10(df_prog['mcpop'])
df_prog['target'].describe()
# Out:
# count    184.000000
# mean      -3.699177
# std        0.718307
# min       -5.027659
# 25%       -4.252000
# 50%       -3.767311
# 75%       -3.108420
# max       -0.748642
# Name: target, dtype: float64

# %% [markdown]
# For looking at country behavior we try the ACAPS government measures dataset.

# %%
df_meas = pd.read_excel('acaps_covid19_government_measures_datasets.xlsx', sheet_name='Database')
df_meas
# Out:
#           ID      COUNTRY  ISO ADMIN_LEVEL_NAME  PCODE  REGION  \
# 0          1  Afghanistan  AFG              NaN    NaN    Asia
# 1          2  Afghanistan  AFG            Kabul    NaN    Asia
# 2          3  Afghanistan  AFG              NaN    NaN    Asia
# 3          4  Afghanistan  AFG              NaN    NaN    Asia
# 4          5  Afghanistan  AFG              NaN    NaN    Asia
# ...      ...          ...  ...              ...    ...     ...
# 12533  11771     Zimbabwe  ZWE              NaN    NaN  Africa
# 12534  11772     Zimbabwe  ZWE              NaN    NaN  Africa
# 12535  11773     Zimbabwe  ZWE              NaN    NaN  Africa
# 12536  11774     Zimbabwe  ZWE              NaN    NaN  Africa
# 12537  11775     Zimbabwe  ZWE              NaN    NaN  Africa
#
#                                    LOG_TYPE  \
# 0      Introduction / extension of measures
# 1      Introduction / extension of measures
# 2      Introduction / extension of measures
# 3      Introduction / extension of measures
# 4      Introduction / extension of measures
# ...                                     ...
# 12533  Introduction / extension of measures
# 12534  Introduction / extension of measures
# 12535  Introduction / extension of measures
# 12536                     Phase-out measure
# 12537                     Phase-out measure
#
#                                      CATEGORY  \
# 0                      Public health measures
# 1                      Public health measures
# 2                      Public health measures
# 3      Governance and socio-economic measures
# 4                           Social distancing
# ...                                       ...
# 12533                                Lockdown
# 12534                  Public health measures
# 12535                                Lockdown
# 12536                       Social distancing
# 12537                       Social distancing
#
#                                                  MEASURE TARGETED_POP_GROUP  \
# 0      Health screenings in airports and border cross...                 No
# 1                      Isolation and quarantine policies                 No
# 2                                    Awareness campaigns                 No
# 3      Emergency administrative structures activated ...                 No
# 4                                Limit public gatherings                 No
# ...                                                  ...                ...
# 12533                                   Partial lockdown                 No
# 12534      Requirement to wear protective gear in public                 No
# 12535                                   Partial lockdown                 No
# 12536                            Limit public gatherings                 No
# 12537                            Limit public gatherings                 No
#
#                                                 COMMENTS    NON_COMPLIANCE  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                              Nevruz festival cancelled               NaN
# ...                                                  ...               ...
# 12533  Partial lockdown (level 2) extended indefinite...     Not available
# 12534  The government of Zimbabwe has officially made...  Arrest/Detention
# 12535           Zimbabwe extends lockdown until May 15th     Not available
# 12536  Outdoor exercises like walking or jogging or c...    Not applicable
# 12537  Athletes taking part in low-risk sports, inclu...    Not applicable
#
#       DATE_IMPLEMENTED               SOURCE SOURCE_TYPE  \
# 0           2020-02-12   Ministry of Health  Government
# 1           2020-02-12   Ministry of Health  Government
# 2           2020-02-12   Ministry of Health  Government
# 3           2020-02-12   Ministry of Health  Government
# 4           2020-03-12                   AA       Media
# ...                ...                  ...         ...
# 12533       2020-05-17  Zimbabwe Government  Government
# 12534       2020-05-04          Africa News       Media
# 12535       2020-05-04                Garda       Media
# 12536       2020-05-17  Zimbabwe Government  Government
# 12537       2020-05-17  Zimbabwe Government  Government
#
#                                                     LINK ENTRY_DATE  \
# 0      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 1      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 2      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 3      https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 4      https://www.aa.com.tr/en/asia-pacific/coronavi... 2020-03-14
# ...                                                  ...        ...
# 12533  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
# 12534  https://www.africanews.com/2020/05/10/zimbabwe... 2020-05-25
# 12535  https://www.garda.com/crisis24/news-alerts/339... 2020-05-25
# 12536  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
# 12537  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
#
#                                       Alternative source
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12533   https://zw.usembassy.gov/covid-19-information-2/
# 12534  https://www.garda.com/crisis24/news-alerts/339...
# 12535                                                NaN
# 12536                                                NaN
# 12537                                                NaN
#
# [12538 rows x 18 columns]

# %% [markdown]
# The dataset contains both start and end of measures, so let's see how they are coded.

# %%
print(df_meas['LOG_TYPE'].unique())
df_meas = df_meas[df_meas['LOG_TYPE'] == 'Introduction / extension of measures']
# Out:
# ['Introduction / extension of measures' 'Phase-out measure']

# %% [markdown]
# Both datasets contain the three character ISO country code, so we join on those columns.

# %%
df_full = pd.merge(df_prog, df_meas, left_on='iso3', right_on='ISO')
df_full
# Out:
#      iso2                 cname iso3   ccont     popdata  rsquared  progress  \
# 0      AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994810  0.687086
# 1      AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994810  0.687086
# 2      AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994810  0.687086
# 3      AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994810  0.687086
# 4      AE  United_Arab_Emirates  ARE    Asia   9630959.0  0.994810  0.687086
# ...   ...                   ...  ...     ...         ...       ...       ...
# 9265   ZW              Zimbabwe  ZWE  Africa  14439018.0  0.964637  1.499994
# 9266   ZW              Zimbabwe  ZWE  Africa  14439018.0  0.964637  1.499994
# 9267   ZW              Zimbabwe  ZWE  Africa  14439018.0  0.964637  1.499994
# 9268   ZW              Zimbabwe  ZWE  Africa  14439018.0  0.964637  1.499994
# 9269   ZW              Zimbabwe  ZWE  Africa  14439018.0  0.964637  1.499994
#
#              final      start       peak  ...  \
# 0     52857.328283 2020-03-22 2020-05-14  ...
# 1     52857.328283 2020-03-22 2020-05-14  ...
# 2     52857.328283 2020-03-22 2020-05-14  ...
# 3     52857.328283 2020-03-22 2020-05-14  ...
# 4     52857.328283 2020-03-22 2020-05-14  ...
# ...            ...        ...        ...  ...
# 9265    150.286268 2020-06-01 2020-06-02  ...
# 9266    150.286268 2020-06-01 2020-06-02  ...
# 9267    150.286268 2020-06-01 2020-06-02  ...
# 9268    150.286268 2020-06-01 2020-06-02  ...
# 9269    150.286268 2020-06-01 2020-06-02  ...
#
#                                                 MEASURE  TARGETED_POP_GROUP  \
# 0                                     Visa restrictions                 Yes
# 1                                     Visa restrictions                  No
# 2                      International flights suspension                 Yes
# 3     Health screenings in airports and border cross...                 Yes
# 4     Health screenings in airports and border cross...                  No
# ...                                                 ...                 ...
# 9265                                  Economic measures                  No
# 9266                 Changes in prison-related policies                 Yes
# 9267                                   Partial lockdown                  No
# 9268      Requirement to wear protective gear in public                  No
# 9269                                   Partial lockdown                  No
#
#                                                COMMENTS    NON_COMPLIANCE  \
# 0     entry ban for travellers from Iran (no governm...               NaN
# 1         suspension of visa issuance starting March 17               NaN
# 2     flights to and from Iran and China are suspend...               NaN
# 3     passengers arriving from China will undergo he...               NaN
# 4          health sreenings for all passengers arriving               NaN
# ...                                                 ...               ...
# 9265  Both residential & commercial properties will ...    Not applicable
# 9266  Zimbabwe frees all female prisoners save those...    Not applicable
# 9267  Partial lockdown (level 2) extended indefinite...     Not available
# 9268  The government of Zimbabwe has officially made...  Arrest/Detention
# 9269           Zimbabwe extends lockdown until May 15th     Not available
#
#       DATE_IMPLEMENTED                       SOURCE   SOURCE_TYPE  \
# 0           2020-01-02                      Reuters         Media
# 1           2020-03-17                          NYT         Media
# 2           2020-03-17  Ministry of Foreign Affairs    Government
# 3           2020-01-23                 KhaleejTimes         Media
# 4           2020-03-08                   US Embassy    Government
# ...                ...                          ...           ...
# 9265        2020-04-28      Ministry of Information  Social media
# 9266        2020-05-01                          BBC         Media
# 9267        2020-05-17          Zimbabwe Government    Government
# 9268        2020-05-04                  Africa News         Media
# 9269        2020-05-04                        Garda         Media
#
#                                                    LINK ENTRY_DATE  \
# 0     https://www.reuters.com/article/us-healthcare-... 2020-03-16
# 1     https://www.nytimes.com/reuters/2020/03/14/wor... 2020-03-16
# 2     https://www.mofaic.gov.ae/en/mediahub/news/202... 2020-03-16
# 3     https://www.khaleejtimes.com/uae/dubai/china-c... 2020-03-16
# 4        https://ae.usembassy.gov/covid-19-information/ 2020-03-16
# ...                                                 ...        ...
# 9265  https://twitter.com/MinOfInfoZW/status/1255190... 2020-04-30
# 9266         https://www.bbc.com/news/world/africa/live 2020-05-04
# 9267  http://www.zim.gov.zw/index.php/en/news-room/l... 2020-05-25
# 9268  https://www.africanews.com/2020/05/10/zimbabwe... 2020-05-25
# 9269  https://www.garda.com/crisis24/news-alerts/339... 2020-05-25
#
#                                      Alternative source
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9265                                                NaN
# 9266                                                NaN
# 9267   https://zw.usembassy.gov/covid-19-information-2/
# 9268  https://www.garda.com/crisis24/news-alerts/339...
# 9269                                                NaN
#
# [9270 rows x 34 columns]

# %% [markdown]
# The first analysis could be how early measures were implemented, so we calculate the difference between the implemented date and our estimated start date in days.

# %%
df_full['days'] = (df_full['DATE_IMPLEMENTED'] - df_full['start']).dt.days
df_full['days'].describe()
# Out:
# count    8956.000000
# mean        9.157213
# std        34.970577
# min      -146.000000
# 25%       -11.000000
# 50%         9.000000
# 75%        33.000000
# max       162.000000
# Name: days, dtype: float64

# %% [markdown]
# To reduce this to a source dataset for modeling, we filter on introduction of measures and pivot to columns with the average number of days for categories, indexed by country code.

# %%
df_aggr = df_full.pivot_table(index='iso2', columns='CATEGORY', values='days')
df_aggr
# Out:
# CATEGORY  Governance and socio-economic measures  Humanitarian exemption  \
# iso2
# AE                                      2.000000                     NaN
# AF                                    -53.800000                     NaN
# AG                                      7.400000                     NaN
# AL                                     10.733333                     NaN
# AM                                     32.750000                     NaN
# ...                                          ...                     ...
# VC                                           NaN                     NaN
# VE                                    -36.111111                     NaN
# ZA                                     11.933333                     NaN
# ZM                                    -36.000000                     NaN
# ZW                                    -47.200000                     NaN
#
# CATEGORY  Lockdown  Movement restrictions  Public health measures  \
# iso2
# AE            14.5              12.571429               -3.200000
# AF           -21.0             -53.375000              -47.343750
# AG            24.6               3.000000               -2.300000
# AL            25.5              10.833333              -11.272727
# AM            26.0              11.384615               19.000000
# ...            ...                    ...                     ...
# VC             NaN                    NaN                2.777778
# VE           -49.0             -44.555556              -31.600000
# ZA            -2.5              12.000000               17.411765
# ZM             NaN             -31.166667              -42.636364
# ZW           -37.0             -69.000000              -62.000000
#
# CATEGORY  Social distancing
# iso2
# AE                17.500000
# AF               -35.333333
# AG                -2.857143
# AL                 4.125000
# AM                11.750000
# ...                     ...
# VC                -3.000000
# VE               -65.400000
# ZA                 7.727273
# ZM               -48.833333
# ZW               -61.400000
#
# [157 rows x 6 columns]

# %% [markdown]
# The final dataset contains this data combined with our estimates.

# %%
df_final = pd.merge(df_prog, df_aggr, left_on='iso2', right_index=True)
df_final.reset_index(drop=True, inplace=True)
df_final
# Out:
#     iso2                             cname iso3    ccont     popdata  \
# 0     AE              United_Arab_Emirates  ARE     Asia   9630959.0
# 1     AF                       Afghanistan  AFG     Asia  37172386.0
# 2     AG               Antigua_and_Barbuda  ATG  America     96286.0
# 3     AL                           Albania  ALB   Europe   2866376.0
# 4     AM                           Armenia  ARM   Europe   2951776.0
# ..   ...                               ...  ...      ...         ...
# 152   VC  Saint_Vincent_and_the_Grenadines  VCT  America    110210.0
# 153   VE                         Venezuela  VEN  America  28870195.0
# 154   ZA                      South_Africa  ZAF   Africa  57779622.0
# 155   ZM                            Zambia  ZMB   Africa  17351822.0
# 156   ZW                          Zimbabwe  ZWE   Africa  14439018.0
#
#      rsquared  progress         final      start       peak  ...          mu  \
# 0    0.994810  0.687086  5.285733e+04 2020-03-22 2020-05-14  ...  134.802109
# 1    0.996008  0.175963  9.835843e+04 2020-04-18 2020-07-02  ...  183.783975
# 2    0.944507  1.272729  1.885712e+01 2020-03-25 2020-04-03  ...   93.869789
# 3    0.986111  0.883503  1.323303e+03 2020-03-13 2020-04-21  ...  111.534498
# 4    0.973406  0.197584  5.365097e+04 2020-03-09 2020-07-14  ...  195.569792
# ..        ...       ...           ...        ...        ...  ...         ...
# 152  0.837054  0.859517  2.908607e+01 2020-03-21 2020-04-26  ...  117.236087
# 153  0.985571  0.873017  2.181925e+03 2020-05-20 2020-05-31  ...  151.981134
# 154  0.982011  0.020943  1.700736e+06 2020-04-05 2020-10-15  ...  289.050346
# 155  0.991399  1.116582  9.833581e+02 2020-05-10 2020-05-18  ...  138.763116
# 156  0.964637  1.499994  1.502863e+02 2020-06-01 2020-06-02  ...  153.444411
#
#             maxcur     mcpop    target  \
# 0     10052.922187  0.001044 -2.981377
# 1     11860.256406  0.000319 -3.496126
# 2        14.004713  0.000145 -3.837289
# 3       254.030214  0.000089 -4.052448
# 4      4443.601391  0.001505 -2.822348
# ..             ...       ...       ...
# 152       5.017248  0.000046 -4.341755
# 153    1105.505035  0.000038 -4.416889
# 154  101277.107740  0.001753 -2.756263
# 155     668.495820  0.000039 -4.414246
# 156     135.481043  0.000009 -5.027659
#
#      Governance and socio-economic measures  Humanitarian exemption  Lockdown  \
# 0                                  2.000000                     NaN      14.5
# 1                                -53.800000                     NaN     -21.0
# 2                                  7.400000                     NaN      24.6
# 3                                 10.733333                     NaN      25.5
# 4                                 32.750000                     NaN      26.0
# ..                                      ...                     ...       ...
# 152                                     NaN                     NaN       NaN
# 153                              -36.111111                     NaN     -49.0
# 154                               11.933333                     NaN      -2.5
# 155                              -36.000000                     NaN       NaN
# 156                              -47.200000                     NaN     -37.0
#
#      Movement restrictions  Public health measures  Social distancing
# 0                12.571429               -3.200000          17.500000
# 1               -53.375000              -47.343750         -35.333333
# 2                 3.000000               -2.300000          -2.857143
# 3                10.833333              -11.272727           4.125000
# 4                11.384615               19.000000          11.750000
# ..                     ...                     ...                ...
# 152                    NaN                2.777778          -3.000000
# 153             -44.555556              -31.600000         -65.400000
# 154              12.000000               17.411765           7.727273
# 155             -31.166667              -42.636364         -48.833333
# 156             -69.000000              -62.000000         -61.400000
#
# [157 rows x 22 columns]

# %% [markdown]
# Just a quick check on data, for example the relation between beta (the Gumbel curve width parameter) and the target column.

# %%
df_final.plot(kind="scatter", x="beta", y="target", alpha=1/2)

# %% [markdown]
# If we start using this model for predictions, we need to split the dataset. For now we are still exploring so we use all the data for analysis. The feature columns are all the columns added to the right of our dataset with estimations.

# %%
from sklearn.model_selection import train_test_split

featcols = len(df_prog.columns)
features = df_final.columns[featcols:]

#x_trn, x_tst, y_trn, y_tst = train_test_split(df_final[features], df_final['mcpop'])

x_trn = df_final[features]
y_trn = df_final['target']

# %% [markdown]
# Create the XGBoost data structure for training and check parameters to prevent overfitting on this small dataset. Then check the error rate between the test and train data used internally by XGBoost. If the test error rate is much higher, we are overfitting.

# %%
import xgboost as xgb

dtrn = xgb.DMatrix(x_trn, label=y_trn)
#dtst = xgb.DMatrix(x_tst)

params = {
    #'objective':'reg:squarederror',
    'eta':1/10,
    'gamma':1,
    #'min_child_weight':10,
    #'tree_method':'hist',
    'seed':0,
    'max_depth':3,
    'colsample_bytree':0.7,
    'subsample':0.7,
}

hist = xgb.cv(params, dtrn, nfold=10, as_pandas=True, num_boost_round=100, verbose_eval=10, early_stopping_rounds=1000, show_stdv=True, seed=0)
hist.plot(y=["test-rmse-mean", "train-rmse-mean"])
# Out:
# [0]	train-rmse:3.88061+0.01220	test-rmse:3.88056+0.12300
# [10]	train-rmse:1.46603+0.00823	test-rmse:1.47478+0.12064
# [20]	train-rmse:0.69037+0.00431	test-rmse:0.72463+0.10238
# [30]	train-rmse:0.49090+0.00611	test-rmse:0.56215+0.07630
# [40]	train-rmse:0.44696+0.00861	test-rmse:0.54322+0.07110
# [50]	train-rmse:0.43352+0.00924	test-rmse:0.54374+0.06832
# [60]	train-rmse:0.42600+0.00943	test-rmse:0.54567+0.06682
# [70]	train-rmse:0.41882+0.00881	test-rmse:0.54889+0.06505
# [80]	train-rmse:0.41391+0.00888	test-rmse:0.55206+0.06650
# [90]	train-rmse:0.40933+0.00818	test-rmse:0.55271+0.06785
# [99]	train-rmse:0.40580+0.00744	test-rmse:0.55282+0.06827

# %% [markdown]
# Train the model using the parameters found above and show the feature importance. Note that this can be both a positive and negative influence.

# %%
bst = xgb.train(params, dtrn, num_boost_round=100, verbose_eval=1)

import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(16, 9))

xgb.plot_importance(bst, ax=ax, height=1/2)

# %% [markdown]
# The actual XGBoost model is an ensemble of decision trees that can be hard to interpret. SHAP is an analysis library that shows the influence of factors based on this model. First we choose a country and see how the estimate relates to measures.

# %%
country = 'NL'

rownum = df_final[df_final['iso2'] == country].index[0]

import shap

shap.initjs()

explainer = shap.TreeExplainer(bst, x_trn)
shap_values = explainer.shap_values(x_trn)

shap.force_plot(explainer.expected_value, shap_values[rownum], x_trn.loc[rownum])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iWW6YJXNE2SE58UZYJJ6X'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": -3.756042012388508, "outValue": -3.5810084072025834, "link": "identity", "featureNames": ["Governance and socio-economic measures", "Humanitarian exemption", "Lockdown", "Movement restrictions", "Public health measures", "Social distancing"], "features": {"0": {"effect": -0.08690388171168364, "value": 11.5}, "1": {"effect": -0.0012348788274321586, "value": NaN}, "2": {"effect": -0.023971414857893992, "value": NaN}, "3": {"effect": -0.0511627832997092, "value": NaN}, "4": {"effect": 0.20923333867174235, "value": 51.57142857142857}, "5": {"effect": 0.12907322521090128, "value": 27.857142857142858}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iWW6YJXNE2SE58UZYJJ6X')
#   );
# </script>

# %% [markdown]
# When we take all these plots, rotate and stack them we get a global view of the model.

# %%
shap.force_plot(explainer.expected_value, shap_values, x_trn)
# Out:
# <div id='iAX3BWV8J72714HS1ZSVG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["model output value"], "baseValue": -3.756042012388508, "link": "identity", "featureNames": ["Governance and socio-economic measures", "Humanitarian exemption", "Lockdown", "Movement restrictions", "Public health measures", "Social distancing"], "explanations": [{"outValue": -3.6394237460593386, "simIndex": 71.0, "features": {"0": {"effect": 0.007960792272025423, "value": 2.0}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": 0.009611657565566385, "value": 14.5}, "3": {"effect": 0.010508923945580699, "value": 12.571428571428571}, "4": {"effect": -0.03148423726403504, "value": -3.2}, "5": {"effect": 0.12133637937912896, "value": 17.5}}}, {"outValue": -4.089185163534244, "simIndex": 138.0, "features": {"0": {"effect": -0.06357220790176919, "value": -53.8}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": -0.0010090897891931474, "value": -21.0}, "3": {"effect": 0.11019024519831132, "value": -53.375}, "4": {"effect": -0.33049137519292865, "value": -47.34375}, "5": {"effect": -0.04694547389106006, "value": -35.333333333333336}}}, {"outValue": -3.7680877269300184, "simIndex": 80.0, "features": {"0": {"effect": -0.0049349140452968464, "value": 7.4}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": 0.0364587298730851, "value": 24.6}, "3": {"effect": -0.006017365047981026, "value": 3.0}, "4": {"effect": -0.02704772103138885, "value": -2.3}, "5": {"effect": -0.009189194720831646, "value": -2.857142857142857}}}, {"outValue": -4.017078597722746, "simIndex": 76.0, "features": {"0": {"effect": -0.05752163623892673, "value": 10.733333333333333}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": 0.0364587298730851, "value": 25.5}, "3": {"effect": -0.025493238400074707, "value": 10.833333333333334}, "4": {"effect": -0.18155191684806138, "value": -11.272727272727273}, "5": {"effect": -0.03161327415116274, "value": 4.125}}}, {"outValue": -3.293624604067277, "simIndex": 36.0, "features": {"0": {"effect": 0.15178140095630838, "value": 32.75}, "1": {"effect": -0.001208760010398877, "value": NaN}, "2": {"effect": 0.05900103121307815, "value": 26.0}, "3": {"effect": -0.02064499514663865, "value": 11.384615384615385}, "4": {"effect": 0.3134708227070677, "value": 19.0}, "5": {"effect": -0.03998209139818599, "value": 11.75}}}, {"outValue": -3.8289509092879874, "simIndex": 106.0, "features": {"0": {"effect": -0.06143053934559416, "value": 12.290322580645162}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": -0.0050215180548038455, "value": 18.0}, "3": {"effect": -0.006017365047981026, "value": 1.5454545454545454}, "4": {"effect": 0.010064969838828227, "value": 2.0}, "5": {"effect": -0.009189194720831646, "value": -17.25}}}, {"outValue": -3.099482487003092, "simIndex": 50.0, "features": {"0": {"effect": 0.2122469054724855, "value": 34.78947368421053}, "1": {"effect": -0.0011283892687338933, "value": NaN}, "2": {"effect": 0.028836229454227695, "value": 21.0}, "3": {"effect": -0.052670796010287325, "value": 16.363636363636363}, "4": {"effect": 0.32938249224268945, "value": 37.16129032258065}, "5": {"effect": 0.13989308349503454, "value": 27.846153846153847}}}, {"outValue": -3.539859447607312, "simIndex": 28.0, "features": {"0": {"effect": -0.09633760506904145, "value": 20.85}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": -0.002430685368740255, "value": 12.0}, "3": {"effect": -0.12221620376014215, "value": 18.5}, "4": {"effect": 0.30074594734728954, "value": 25.05263157894737}, "5": {"effect": 0.13773636120092717, "value": 25.73076923076923}}}, {"outValue": -3.7494896815533254, "simIndex": 92.0, "features": {"0": {"effect": -0.006350595032452208, "value": 1.6666666666666667}, "1": {"effect": -0.0013152495690971423, "value": NaN}, "2": {"effect": 0.007697980696703219, "value": 7.833333333333333}, "3": {"effect": 0.009814865875301088, "value": -7.7777 ...

# %% [markdown]
# Looking at individual measures we can visualize their impact on model output.

# %%
shap.summary_plot(shap_values, x_trn)

# %% [markdown]
# Finally, a similar plot to the importance plot above shows the explanatory value of measures.

# %%
shap.summary_plot(shap_values, x_trn, plot_type="bar")

# %% [markdown]
# Keep exploring! Stay home, wash your hands, keep your distance.
